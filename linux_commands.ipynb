# %%
"""Linux Commands:

- apt: advanced package tool permite gestionar y administrar paquetes 
- apt-get: instala paquetes desde consola
- lsb_release -a: muestra información de la versión y distribución
- lsb_release -c: muestra el nombre en código
- lsb_release -d: muestra la descripción de la distribución GNU/Linux
- lsb_release -i: muestra el nombre de la distribución
- lsb_release -r: muestra la versión de la distribución
- cat: permite leer el contenido de archivos
- cat -n: muestra las lineas del archivo
- cd: cambia de directorio
- clear: limpia la consola
- cp: copia archivos o directorios
- curl: client URL
- curl -4 icanhazip.com: devuelve la IP pública
- find . -iname: se pueden encontrar archivos 
- ifconfig: permite ver el estado de las interfaces de red
- ls: lista archivos en un directorio
- ls -a: lista archivos ocultos
- ls -l: contenido detallado
- hostname -I: muestra la dirección del host
- net-tools: colección de programas que forman la base del trabajo en red de Linux
- netstat: muestra las conexiones de red, tablas de encaminamiento y estadísticas de las interfaces
- nmap: herramienta de escaneo de puertos y descubrimiento de hosts 
- mkdir: crea una carpeta o directorio
- mv: mueve directorios o archivos o renombra
- pass: cambia la contraseña de un usuario
- pwd: personal working directory o ruta actual
- rm: elimina archivos
- rmdir: elimina carpetas vacias
- root: superusuario posee todos los derechos en todos los modos (cuenta de administrador)
- ssh: secure shell entrega acceso remoto a un servidor por medio de un canal seguro cifrado
. touch: crea nuevos archivos en el directorio actual
- sudo: permite ejecutar programas con privilegios de seguridad de usuario root
- sudo apt update: actualiza las versiones de los paquetes
- ufw: uncomplicated firewall
- uwf allow 80: permite las conexiones entrantes por el puerto 80
- uwf status: muestra el estado del ufw
- whoami: muestra el nombre de usuario

- LSB: linux standard base
- GNOME: entorno de escritorio para GNU/Linux
- GNU: familia de sistemas operativos UNIX
- extensión .deb: archivos ejecutables de las distribuciones Linux basadas en Debian
- enp4s0: dispositivo ethernet (predictable interface names)
- wlp2s0: dispositivo wlan (predictable interface names)
- puerto 22: conexiones seguras SSH y SFTP
- puerto 80: navegación web de forma no segura HTTP
- puerto 8080: alternativo al puerto 80 TCP para servidor web (pruebas)
- CLI: interfaz de linea de comandos
- REPL: lectura, evaluación, impresión, bucle
- apache: servidor HTTP

- CTRL + K: limpia todo a la derecha
"""
